# %%
import pandas as pd

tab = pd.read_csv("mower_market_snapshot.csv", sep = ";")
#1

tab.head(1400)
# Out:
#        capacity  failure_rate     id      margin       price  \
# 0     10.492623      0.042528  18377  633.766584  828.802103
# 1     20.273730      0.037896  19363  731.576817  882.894916
# 2     20.190457      0.039111  19641  741.218202  919.355522
# 3     27.220131      0.041303  18728  654.255635  817.085097
# 4     16.370911      0.037938  18722  703.094527  844.581465
# ...         ...           ...    ...         ...         ...
# 1394  44.959895      0.234647  18451   63.662561   75.161102
# 1395  59.356058      0.253694  18663   64.014543   75.395132
# 1396  67.865222      0.228935  19169   62.132035  810.883148
# 1397  66.855435      0.244948  18946   58.697122   68.491318
# 1398  54.712713      0.177143  19017   64.259212   74.955428
#
#                prod_cost product_type quality warranty  market_share  \
# 0     195.03551928211797  auto-portee     Low     3ans      0.006360
# 1     151.31809934886763  auto-portee     Low   3 ans.      0.006840
# ...

# %%
print(tab['prod_cost'].describe())

#3
# Out:
# count     1381
# unique    1333
# top          0
# freq        20
# Name: prod_cost, dtype: object

# %%
(tab['prod_cost'].describe())
# Out:
# (1399,)

# %%
tab.fillna(tab.mean())
#5
# Out:
#        capacity  failure_rate     id      margin       price  \
# 0     10.492623      0.042528  18377  633.766584  828.802103
# 1     20.273730      0.037896  19363  731.576817  882.894916
# 2     20.190457      0.039111  19641  741.218202  919.355522
# 3     27.220131      0.041303  18728  654.255635  817.085097
# 4     16.370911      0.037938  18722  703.094527  844.581465
# ...         ...           ...    ...         ...         ...
# 1394  44.959895      0.234647  18451   63.662561   75.161102
# 1395  59.356058      0.253694  18663   64.014543   75.395132
# 1396  67.865222      0.228935  19169   62.132035  810.883148
# 1397  66.855435      0.244948  18946   58.697122   68.491318
# 1398  54.712713      0.177143  19017   64.259212   74.955428
#
#                prod_cost product_type quality warranty  market_share  \
# 0     195.03551928211797  auto-portee     Low     3ans      0.006360
# 1     151.31809934886763  auto-portee     Low   3 ans.      0.006840
# ...

# %%
tab.isnull().sum() #4
# Out:
# capacity           0
# failure_rate       0
# id                 0
# margin             0
# price              0
# prod_cost         18
# product_type       0
# quality            0
# warranty           0
# market_share       0
# attractiveness     0
# dtype: int64

# %%
print(tab["warranty"].unique())
#6
# Out:
# ['3ans' '3 ans.' '3_ans' '3 anss' '3ans.' '3 ans' '3_ans.' '3_anss'
#  '3anss' '2 ans' '2 anss' '2anss' '2_ans' '2ans' '2_ans.' '2 ans.'
#  '2_anss' '2ans.' '1 an' '1an' '1_an.' '1ans' '1an.' '1_ans' '1_an'
#  '1 an.' '1 ans']

# %%
tab.isnull().len()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-c9c50ed0a7cd> in <module>
# ----> 1 tab.isnull().len()
#
# /opt/conda/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'len'

# %%
print(tab['prod_cost'].describe())
# Out:
# count     1381
# unique    1333
# top          0
# freq        20
# Name: prod_cost, dtype: object

# %%
tab['warranty'] = tab['warranty'].str[0]
tab['warranty'] = pd.to_numeric(tab['warranty'])
tab.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-287ced2801bd> in <module>
# ----> 1 tab['warranty'] = tab['warranty'].str[0]
#       2 tab['warranty'] = pd.to_numeric(tab['warranty'])
#       3 tab.head()
#
# /opt/conda/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5459             or name in self._accessors
#    5460         ):
# -> 5461             return object.__getattribute__(self, name)
#    5462         else:
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# /opt/conda/lib/python3.8/site-packages/pandas/core/accessor.py in __get__(self, obj, cls)
#     178             # we're accessing the attribute of the class, i.e., Dataset.geo
#     179             return self._accessor
# --> 180         accessor_obj = self._accessor(obj)
# ...

# %%
tab["warranty"] = tab["warranty"].str[0].astype(int)
tab["warranty"].unique()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-245e639d1a29> in <module>
# ----> 1 tab["warranty"] = tab["warranty"].str[0].astype(int)
#       2 tab["warranty"].unique()
#
# /opt/conda/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5459             or name in self._accessors
#    5460         ):
# -> 5461             return object.__getattribute__(self, name)
#    5462         else:
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# /opt/conda/lib/python3.8/site-packages/pandas/core/accessor.py in __get__(self, obj, cls)
#     178             # we're accessing the attribute of the class, i.e., Dataset.geo
#     179             return self._accessor
# --> 180         accessor_obj = self._accessor(obj)
#     181         # Replace the property with the accessor object. Inspired by:
# ...

# %%
tab["warranty"] = tab["warranty"].str[0].astype(int)
tab["warranty"].unique()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-3ae45ff3241f> in <module>
#       1 tab["warranty"].shape
# ----> 2 tab["warranty"] = tab["warranty"].str[0].astype(int)
#       3 tab["warranty"].unique()
#
# /opt/conda/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5459             or name in self._accessors
#    5460         ):
# -> 5461             return object.__getattribute__(self, name)
#    5462         else:
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# /opt/conda/lib/python3.8/site-packages/pandas/core/accessor.py in __get__(self, obj, cls)
#     178             # we're accessing the attribute of the class, i.e., Dataset.geo
#     179             return self._accessor
# --> 180         accessor_obj = self._accessor(obj)
# ...

# %%
tab["warranty"].unique()
#8
# Out:
# array([3, 2, 1])

# %%
print(tab["warranty"].unique())
# Out:
# [3 2 1]

# %%
tab["warranty"] = tab["warranty"].str[0].astype(int)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-6026b91ef1e7> in <module>
# ----> 1 tab["warranty"] = tab["warranty"].str[0].astype(int)
#
# /opt/conda/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5459             or name in self._accessors
#    5460         ):
# -> 5461             return object.__getattribute__(self, name)
#    5462         else:
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# /opt/conda/lib/python3.8/site-packages/pandas/core/accessor.py in __get__(self, obj, cls)
#     178             # we're accessing the attribute of the class, i.e., Dataset.geo
#     179             return self._accessor
# --> 180         accessor_obj = self._accessor(obj)
#     181         # Replace the property with the accessor object. Inspired by:
# ...

# %%
categorie1 = tab[(tab["price"]>0) & (tab["price"]<=300)]
categorie2 = tab[(tab["price"]>=301) & (tab["price"]<=500)]
categorie3 = tab[tab["price"]>=501]
#9

# %%
tab.loc[tab["product_type"]=='auto-portee',"product_type"]=1
tab.loc[tab["product_type"]=='electrique',"product_type"]=2
tab.loc[tab["product_type"]=='essence',"product_type"]=3
#10

# %%
tab["product_type"].unique()
#10
# Out:
# array([1, 2, 3], dtype=object)

# %%
tab["auto-portee"]=0
tab["electrique"]=0
tab["essence"]=0
#11

# %%
tab.loc[tab["product_type"]==1,"auto-portee"]=1
tab.loc[tab["product_type"]==2,"electrique"]=1
tab.loc[tab["product_type"]==3,"essence"]=1
#11

# %%
tab
#11
# Out:
#        capacity  failure_rate     id      margin       price  \
# 0     10.492623      0.042528  18377  633.766584  828.802103
# 1     20.273730      0.037896  19363  731.576817  882.894916
# 2     20.190457      0.039111  19641  741.218202  919.355522
# 3     27.220131      0.041303  18728  654.255635  817.085097
# 4     16.370911      0.037938  18722  703.094527  844.581465
# ...         ...           ...    ...         ...         ...
# 1394  44.959895      0.234647  18451   63.662561   75.161102
# 1395  59.356058      0.253694  18663   64.014543   75.395132
# 1396  67.865222      0.228935  19169   62.132035  810.883148
# 1397  66.855435      0.244948  18946   58.697122   68.491318
# 1398  54.712713      0.177143  19017   64.259212   74.955428
#
#                prod_cost product_type quality  warranty  market_share  \
# 0     195.03551928211797            1     Low         3      0.006360
# 1     151.31809934886763            1     Low         3      0.006840
# ...

# %%
 tab = pd.DataFrame(np.array(['prod_cost']))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-cb2be8c71b80> in <module>
# ----> 1 tab = pd.DataFrame(np.array(['prod_cost']))
#
# NameError: name 'np' is not defined

# %%
import numpy as np
tab = pd.Series(['prod_cost'])
#2

# %%
tab
#2
# Out:
# 0    prod_cost
# dtype: object
